# %% [markdown]
# # Generate PKLs for weekly testing
#
# 1. Import sensor and IBM data
# 2. Sync the data in time
# 3. Create PKLs for 1->52 weeks (or max time length available)
# 4. Test across 30 of them
# 5. Export and save PKLs

# %%
import sqlalchemy as db
import pandas as pd
import numpy as np
import datetime
import pickle

from Namelist import db_info
from Namelist import Account_Station
from Namelist import query_build

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

import sys
sys.path.insert(0, '/Users/mborrus/Benchmark/Downscaling#2/Downscaling/')
from olm import *

sys.path.insert(0, '/Users/mborrus/Benchmark/GCP/ds-common/')
import API_Function_Library.SQL_Functions as SQL_bl

AS_Index = 0;
AccountUid = Account_Station.AccountUid[AS_Index]
StationUid = Account_Station.StationUid[AS_Index]
Provider = Account_Station.Provider[AS_Index]

hostname = db_info['hostname']
dbname = db_info['dbname']
uname = db_info['uname']
pwd = db_info['pwd']

# Create SQLAlchemy engine to connect to MySQL Database
engine = db.create_engine("mysql+pymysql://{user}:{pw}@{host}/{db}"
                       .format(host=hostname, db=dbname, user=uname, pw=pwd))
connection = engine.connect()
metadata = db.MetaData()
Station_Data_table = db.Table('Station_Data', metadata, autoload=True, autoload_with=engine)
IBM_Data_table = db.Table('IBM_Data', metadata, autoload=True, autoload_with=engine)

# %% [markdown]
# #### Import Data
# Import sensor data, then import IBM data for one station

# %%
## Station Data
query = db.select([Station_Data_table]).where(Station_Data_table.columns.stationUid == StationUid)
ResultProxy = connection.execute(query)
ResultSet = ResultProxy.fetchall()
Station_Data = pd.DataFrame(ResultSet)
Station_Data.columns = ResultSet[0].keys()
Station_Data = Station_Data.sort_values(by=['Local_datetime'])

# %%
query = db.select([IBM_Data_table]).where(IBM_Data_table.columns.stationUid == StationUid)
ResultProxy = connection.execute(query)
ResultSet = ResultProxy.fetchall()
IBM_Data = pd.DataFrame(ResultSet)
IBM_Data.columns = ResultSet[0].keys()
IBM_Data = IBM_Data.sort_values(by=['Local_datetime'])

# %% [markdown]
# #### Sync the Data

# %%
Training_Data_All = pd.merge(Station_Data,IBM_Data, how='inner', on = 'Local_datetime',suffixes=('_Sensor', '_IBM'))

# %% [markdown]
# #### Create the pkls

# %%
def Train_Model(Input_Data, Training_var):
    Input_Data=Input_Data.dropna()
    Xdata=Input_Data['%s_IBM' % (Training_var)].to_numpy()
    Ydata=Input_Data['%s_Sensor' % (Training_var)].to_numpy()
    
    comparison = Input_Data['%s_IBM' % (Training_var)].astype(float)
    comparison_lectures = Input_Data['%s_Sensor' % (Training_var)].astype(float)

    XData=Xdata.reshape(Xdata.shape[0],1).astype(float) #first version
    YData=Ydata.reshape(Ydata.shape[0],1).astype(float)
    n_blocks=5
    rowstodrop=len(Xdata)%n_blocks
    XData=XData[rowstodrop:]
    YData=YData[rowstodrop:]
    hn = 15 # define number of hidden neurons (it can change)

    TrainedElm=Elm_train(XData,YData,hn,1,1)
    # TrainedElm=Elm_cross_val(XData,YData,hn)
    logits = Elm_predict(TrainedElm,XData)

    Q1 = comparison_lectures.quantile(0.10)
    TrainedElm['q1'] = Q1

    Q3 = comparison_lectures.quantile(0.90)
    TrainedElm['q3'] = Q3

    weeks = abs(round((Input_Data['Local_datetime'][rowstodrop:].min()-Input_Data['Local_datetime'][rowstodrop:].max()).days/7))
    

    performance_stats = {'MSE_Forecast': [mean_squared_error(YData, logits[0])],
        'MSE_IBM': [mean_squared_error(YData, comparison[rowstodrop:])],
            'MAE_Forecast':[mean_absolute_error(YData, logits[0])],
            'MAE_IBM':[mean_absolute_error(YData, comparison[rowstodrop:])],
            'r2_Forecast':[r2_score(YData, logits[0])],
            'r2_IBM':[r2_score(YData, comparison[rowstodrop:])],
            'weeks': weeks,
            'Model_Date': datetime.date.today(),
            # 'Model_Date': datetime.date.today() - datetime.timedelta(days = 1),
            'Days_Since': (datetime.date.today() - datetime.date.today()).days
        }
    df_performance_temp = pd.DataFrame(performance_stats, columns=['MSE_Forecast','MSE_IBM','MAE_Forecast','MAE_IBM','r2_Forecast','r2_IBM','weeks','Model_Date','Days_Since'])
    return(TrainedElm, df_performance_temp)

def Gladiator_Ring(Input_Data, compare_count=20):
    [model_candidate, perf_candidate]= Train_Model(Input_Data, Training_var)
    for compare in range(0,compare_count):
        [model_gladiator, perf_gladiator]= Train_Model(ST_cut, Training_var)
        if perf_gladiator['MSE_Forecast'].item() <= perf_candidate["MSE_Forecast"].item():
            model_candidate=model_gladiator;
            perf_candidate=perf_gladiator;
            print("Are you not entertained")
    return(model_candidate, perf_candidate)

# %%
first_date = Training_Data_All.Local_datetime.min()
last_date = Training_Data_All.Local_datetime.max()
date_range = round((last_date - first_date).days/7)

# %%
if date_range>=60:
    weeks_count = 60;
    weeks_range = [1,2,3,4,5,6,7,*range(8,weeks_count+1,2)];
elif date_range<=0:
    print("issues with dates (0 or neg)")
    weeks_range = []
elif date_range>=0 & date_range<=8:
    weeks_count = date_range
    weeks_range = [*range(1,weeks_count+1)];
else:
    weeks_count = date_range

# %%
# weeks_count = 5; weeks_range = [*range(1,weeks_count+1)];
Training_var = 'TEMPERATURE'
compare_count = 20;

df_performance_all = pd.DataFrame()
File_Names = [];

for week_length in weeks_range:
    print(str(week_length))
    Start_date = datetime.date.today()
    # Start_date = datetime.date.today() - datetime.timedelta(days = 1)
    End_date = Start_date - datetime.timedelta(weeks=week_length)
    range_eval = pd.eval('(Training_Data_All.Local_datetime.dt.date > End_date) & (Training_Data_All.Local_datetime.dt.date < Start_date)')
    Data_cut = Training_Data_All[range_eval].reset_index()
    [model_candidate, perf_candidate]= Train_Model(Data_cut, Training_var)
    for compare in range(0,compare_count):
        [model_gladiator, perf_gladiator]= Train_Model(Data_cut, Training_var)
        if perf_gladiator['MSE_Forecast'].item() <= perf_candidate["MSE_Forecast"].item():
            model_candidate=model_gladiator;
            perf_candidate=perf_gladiator;
            print("Are you not entertained")
    # TrainedElm_array.append(model_candidate)
    df_performance_all = df_performance_all.append(perf_candidate, ignore_index = True)

    filename = AccountUid+'_'+StationUid+'_'+Training_var+'_'+str(Start_date)+'_'+str(week_length)+".pkl"
    File_Names.append(filename)
    f = open('./pkls/'+filename,"wb")
    pickle.dump(model_candidate,f)
    f.close()

df_performance_all['stationUid'] = StationUid;
df_performance_all['Metric'] = Training_var;
df_performance_all['pkl_file_name'] = File_Names;
# Out:
# 1
# Are you not entertained
# Are you not entertained
# Are you not entertained
# Are you not entertained
# Are you not entertained
# 2
# Are you not entertained
# Are you not entertained
# Are you not entertained
# Are you not entertained
# 3
# Are you not entertained
# Are you not entertained
# Are you not entertained
# Are you not entertained
# 4
# Are you not entertained
# Are you not entertained
# 5
# Are you not entertained
# Are you not entertained
# Are you not entertained
# Are you not entertained
# Are you not entertained
# 6
# Are you not entertained
# Are you not entertained
# Are you not entertained
# 7
# Are you not entertained
# Are you not entertained
# 8
# 10
# Are you not entertained
# Are you not entertained
# 12
# Are you not entertained
# Are you not entertained
# 14
# Are you not entertained
# Are you not entertained
# 16
# Are you not entertained
# Are you not entertained
# Are you not entertained
# Are you not entertained
# 18
# Are you not entertained
# 20
# Are you not entertained
# Are you not entertained
# Are you not entertained
# Are you not entertained
# 22
# Are you not entertained
# Are you not entertained
# Are you not entertained
# 24
# Are you not entertained
# Are you not entertained
# Are you not entertained
# 26
# Are you not entertained
# Are you not entertained
# Are you not entertained
# 28
# Are you not entertained
# Are you not entertained
# 30
# Are you not entertained
# Are you not entertained
# 32
# Are you not entertained
# Are you not entertained
# 34
# Are you not entertained
# 36
# Are you not entertained
# Are you not entertained
# Are you not entertained
# 38
# Are you not entertained
# Are you not entertained
# Are you not entertained
# Are you not entertained
# 40
# Are you not entertained
# Are you not entertained
# Are you not entertained
# Are you not entertained
# 42
# Are you not entertained
# Are you not entertained
# Are you not entertained
# Are you not entertained
# Are you not entertained
# 44
# Are you not entertained
# Are you not entertained
# Are you not entertained
# 46
# Are you not entertained
# Are you not entertained
# 48
# Are you not entertained
# Are you not entertained
# Are you not entertained
# 50
# Are you not entertained
# Are you not entertained
# Are you not entertained
# 52
# Are you not entertained
# Are you not entertained
# Are you not entertained
# 54
# Are you not entertained
# 56
# Are you not entertained
# Are you not entertained
# Are you not entertained
# 58
# Are you not entertained
# Are you not entertained
# Are you not entertained
# Are you not entertained
# 60
# Are you not entertained

# %%
df_performance_all
# Out:
#     MSE_Forecast    MSE_IBM  MAE_Forecast   MAE_IBM  r2_Forecast    r2_IBM  \
# 0       1.037224   4.860121      0.785196  1.881674     0.961541  0.819791
# 1       3.652501   7.444932      1.322877  2.093707     0.889282  0.774321
# 2       7.147951  12.499962      2.157424  2.748317     0.836783  0.714574
# 3       6.473779  12.950020      2.039520  2.828847     0.854900  0.709745
# 4       5.568011  11.177891      1.813099  2.587185     0.867949  0.734906
# 5       5.228374  10.094475      1.769668  2.456800     0.876635  0.761819
# 6       4.835717   9.382609      1.673199  2.363026     0.889162  0.784943
# 7       5.326162   9.153275      1.717275  2.318663     0.889557  0.810198
# 8       4.524101   7.973762      1.502126  2.122982     0.909345  0.840219
# 9       4.449808   7.914021      1.544780  2.111611     0.921394  0.860198
# 10      4.522459   7.693293      1.565589  2.053473     0.932529  0.885223
# 11      4.617707   8.010137      1.578692  2.055265     0.933110  0.883968
# 12      5.075716   9.063541      1.664473  2.130988     0.931374  0.877457
# 13      4.970808   9.232129      1.639307  2.138227     0.931223  0.872263
# 14      4.946496   9.412614      1.634915  2.147310     0.929992  0.866782
# 15      4.949149   9.546899      1.630045  2.151425     0.929247  0.863518
# 16      5.579834  10.563917      1.697021  2.223088     0.920235  0.848987
# 17      5.885435  10.964640      1.734130  2.248637     0.913401  0.838665
# 18      6.260783  11.331887      1.788118  2.276712     0.906804  0.831317
# 19      6.291120  11.176963      1.784825  2.254874     0.905514  0.832133
# 20      6.159554  10.642782      1.761807  2.186091     0.905932  0.837465
# 21      6.276524  10.298137      1.760012  2.145395     0.902888  0.840664
# 22      6.248048   9.931390      1.757531  2.102376     0.902273  0.844660
# 23      6.113952   9.627098      1.735471  2.069169     0.906463  0.852715
# 24      6.206804   9.581716      1.758593  2.074827     0.908446  0.858664
# 25      6.695313   9.892919      1.847431  2.127325     0.903177  0.856935
# 26      6.569518   9.840671      1.833787  2.137502     0.907251  0.861068
# 27      6.602594   9.785841      1.847356  2.137023     0.905826  0.860422
# 28      6.508026   9.640896      1.833903  2.122192     0.908047  0.863783
# 29      6.373307   9.459569      1.812932  2.104133     0.910982  0.867876
# 30      6.420664   9.395036      1.822441  2.099403     0.909276  0.867247
# 31      6.685675   9.446729      1.861536  2.112013     0.903976  0.864320
# 32      6.601205   9.220478      1.840710  2.075548     0.902913  0.864390
# 33      6.658482   9.133258      1.846176  2.066696     0.900500  0.863519
#
#     weeks  Model_Date  Days_Since                            stationUid  \
# 0       1  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 1       2  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 2       3  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 3       4  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 4       5  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 5       6  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 6       7  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 7       8  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 8      10  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 9      12  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 10     14  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 11     16  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 12     18  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 13     20  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 14     22  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 15     24  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 16     26  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 17     28  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 18     30  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 19     32  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 20     34  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 21     36  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 22     38  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 23     40  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 24     42  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 25     44  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 26     46  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 27     48  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 28     50  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 29     52  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 30     54  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 31     56  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 32     58  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
# 33     60  2022-12-06           0  c8a9d548-7fc4-40bb-954e-389988526593
#
#          Metric                                      pkl_file_name
# 0   TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 1   TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 2   TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 3   TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 4   TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 5   TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 6   TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 7   TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 8   TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 9   TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 10  TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 11  TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 12  TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 13  TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 14  TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 15  TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 16  TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 17  TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 18  TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 19  TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 20  TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 21  TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 22  TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 23  TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 24  TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 25  TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 26  TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 27  TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 28  TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 29  TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 30  TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 31  TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 32  TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...
# 33  TEMPERATURE  2a6997a7-a9a2-4b2e-b87a-656d6e85cbaf_c8a9d548-...

# %%
# Create mysql.connection to do merge tables
connection_out = SQL_bl.create_db_connection(hostname, uname, pwd, dbname) # Connect to the Database

df_performance_all.to_sql('Pkl_Performance_Data_Temp', engine, index=False, if_exists = 'replace')

name = "Pkl_Performance";
query_merge = '''
INSERT INTO %s_Data
SELECT %s_Data_Temp.*
FROM %s_Data_Temp
WHERE NOT EXISTS(SELECT * FROM %s_Data 
WHERE %s_Data_Temp.weeks = %s_Data.weeks 
AND %s_Data_Temp.Model_Date = %s_Data.Model_Date 
AND %s_Data_Temp.Days_Since = %s_Data.Days_Since
AND %s_Data_Temp.Metric = %s_Data.Metric
AND %s_Data_Temp.stationUid = %s_Data.stationUid);
''' % (name,name,name,name,name,name,name,name,name,name,name,name,name,name)

SQL_bl.execute_query(connection_out, query_merge) # Execute our defined query
# Out:
# MySQL Database connection successful
# Query successful
